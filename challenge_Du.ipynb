# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix
import numpy as np
from sklearn import preprocessing
from sklearn.decomposition import PCA
from pylab import *
# %matplotlib inline

# %%
votre_path="/Users/asus/Documents/Python Scripts/challenge/"
data_path=votre_path+"Xtrain.csv"
Xtrain=pd.read_csv(data_path,sep = ',',header = 0)
data_path=votre_path+"Ytrain.csv"
Ytrain=pd.read_csv(data_path,sep = ';',header = 0)
data_path=votre_path+"Xtest.csv"
Xtest=pd.read_csv(data_path,sep = ',',header = 0)

# %%
Xtrain.columns[1:750]

# %%
Xtrain.head()
# Out:
#    ID     ML1_0     ML1_1     ML1_2     ML1_3     ML1_4     ML1_5     ML1_6  \
# 0   0  0.021276  0.039363 -0.001475  0.023994  0.009620  0.036350  0.028983
# 1   1  0.018403  0.026159  0.009684  0.001014 -0.000866  0.002019  0.000617
# 2   2 -0.020974 -0.044294 -0.044097 -0.042136 -0.041125 -0.034392 -0.033026
# 3   3 -0.004381 -0.017433 -0.021386 -0.020316 -0.019849 -0.023615 -0.013923
# 4   4  0.022106  0.065815  0.060662  0.063035  0.065413  0.064131  0.061383
#
#       ML1_7     ML1_8    ...       V6_740    V6_741    V6_742    V6_743  \
# 0  0.031416  0.030435    ...    -0.003424 -0.007473 -0.008551 -0.011629
# 1 -0.011167 -0.026314    ...    -0.005327 -0.002014  0.001650  0.004635
# 2 -0.031817 -0.032347    ...    -0.068369 -0.059892 -0.055802 -0.041579
# 3  0.014080  0.088580    ...     0.376336  0.357924  0.333985  0.305791
# 4  0.059843  0.060229    ...    -0.015729 -0.014732 -0.014419 -0.014700
#
#      V6_744    V6_745    V6_746    V6_747    V6_748    V6_749
# ...

# %%
Ytrain.head()
# Out:
#    ID  TARGET
# 0   0       1
# 1   1       1
# 2   2       1
# 3   3       1
# 4   4       0

# %%
def DataSample(X,ID,index):
    'X:dataframe of input data'
    'Id = id, from 0 to 999'
    'index = index of channel, from 1 to 12'
    return X.iloc[ID,1+(index-1)*750:1+index*750]

# %%
##visualisation des datas
##la premiere type de inversion
fig, ((ax1, ax2, ax3), (ax4, ax5,ax6),(ax7, ax8, ax9), (ax10, ax11,ax12)) = plt.subplots(4, 3, sharex='col', sharey='row')
fig.set_size_inches(15, 15)

for (ax,i) in zip((ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12),range(1,13,1)):
    ax.plot(DataSample(Xtrain,0,i))
    ax.set_title('channel '+str(i))

# %%
##la deuxieme type de inversion
fig, ((ax1, ax2, ax3), (ax4, ax5,ax6),(ax7, ax8, ax9), (ax10, ax11,ax12)) = plt.subplots(4, 3, sharex='col', sharey='row')
fig.set_size_inches(15, 15)

for (ax,i) in zip((ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12),range(1,13,1)):
    ax.plot(DataSample(Xtrain,2,i))
    ax.set_title('channel '+str(i))

# %%
##la troiseme type de inversion
fig, ((ax1, ax2, ax3), (ax4, ax5,ax6),(ax7, ax8, ax9), (ax10, ax11,ax12)) = plt.subplots(4, 3, sharex='col', sharey='row')
fig.set_size_inches(15, 15)

for (ax,i) in zip((ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12),range(1,13,1)):
    ax.plot(DataSample(Xtrain,5,i))
    ax.set_title('channel '+str(i))

# %%
##la quartieme type de inversion
fig, ((ax1, ax2, ax3), (ax4, ax5,ax6),(ax7, ax8, ax9), (ax10, ax11,ax12)) = plt.subplots(4, 3, sharex='col', sharey='row')
fig.set_size_inches(15, 15)

for (ax,i) in zip((ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12),range(1,13,1)):
    ax.plot(DataSample(Xtrain,8,i))
    ax.set_title('channel '+str(i))

# %%
##la cinqueme type de inversion
fig, ((ax1, ax2, ax3), (ax4, ax5,ax6),(ax7, ax8, ax9), (ax10, ax11,ax12)) = plt.subplots(4, 3, sharex='col', sharey='row')
fig.set_size_inches(15, 15)

for (ax,i) in zip((ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12),range(1,13,1)):
    ax.plot(DataSample(Xtrain,14,i))
    ax.set_title('channel '+str(i))

# %%
##la correcte type
fig, ((ax1, ax2, ax3), (ax4, ax5,ax6),(ax7, ax8, ax9), (ax10, ax11,ax12)) = plt.subplots(4, 3, sharex='col', sharey='row')
fig.set_size_inches(15, 15)

for (ax,i) in zip((ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12),range(1,13,1)):
    ax.plot(DataSample(Xtrain,4,i))
    ax.set_title('channel '+str(i))

# %%
##feature selected
centre_1=[]
channel = 1
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (1000):
    Xtrain_num  = Xtrain.iloc[i,columne]
    A=pd.Series(Xtrain_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    centre_1.append(centre_loc)

# %%
centre_2=[]
channel = 2
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (1000):
    Xtrain_num  = Xtrain.iloc[i,columne]
    A=pd.Series(Xtrain_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    centre_2.append(centre_loc)

# %%
centre_3=[]
channel = 3
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (1000):
    Xtrain_num  = Xtrain.iloc[i,columne]
    A=pd.Series(Xtrain_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    centre_3.append(centre_loc)

# %%
centre_4=[]
channel = 4
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (1000):
    Xtrain_num  = Xtrain.iloc[i,columne]
    A=pd.Series(Xtrain_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    centre_4.append(centre_loc)

# %%
centre_5=[]
channel = 5
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (1000):
    Xtrain_num  = Xtrain.iloc[i,columne]
    A=pd.Series(Xtrain_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    centre_5.append(centre_loc)

# %%
centre_6=[]
channel = 6
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (1000):
    Xtrain_num  = Xtrain.iloc[i,columne]
    A=pd.Series(Xtrain_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    centre_6.append(centre_loc)

# %%
centre_7=[]
channel = 7
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (1000):
    Xtrain_num  = Xtrain.iloc[i,columne]
    A=pd.Series(Xtrain_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    centre_7.append(centre_loc)

# %%
centre_8=[]
channel = 8
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (1000):
    Xtrain_num  = Xtrain.iloc[i,columne]
    A=pd.Series(Xtrain_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    centre_8.append(centre_loc)

# %%
centre_9=[]
channel = 9
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (1000):
    Xtrain_num  = Xtrain.iloc[i,columne]
    A=pd.Series(Xtrain_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    centre_9.append(centre_loc)

# %%
centre_10=[]
channel = 10
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (1000):
    Xtrain_num  = Xtrain.iloc[i,columne]
    A=pd.Series(Xtrain_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    centre_10.append(centre_loc)

# %%
centre_11=[]
channel = 11
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (1000):
    Xtrain_num  = Xtrain.iloc[i,columne]
    A=pd.Series(Xtrain_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    centre_11.append(centre_loc)

# %%
centre_12=[]
channel = 12
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (1000):
    Xtrain_num  = Xtrain.iloc[i,columne]
    A=pd.Series(Xtrain_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    centre_12.append(centre_loc)

# %%
##pca de feature
X=pd.DataFrame(centre_1)
X_1=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_1)
pca_1 = pca.transform(X_1)

# %%
X=pd.DataFrame(centre_2)
X_2=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_2)
pca_2 = pca.transform(X_2)

# %%
X=pd.DataFrame(centre_3)
X_3=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_3)
pca_3 = pca.transform(X_3)

# %%
X=pd.DataFrame(centre_4)
X_4=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_4)
pca_4 = pca.transform(X_4)

# %%
X=pd.DataFrame(centre_5)
X_5=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_5)
pca_5 = pca.transform(X_5)

# %%
X=pd.DataFrame(centre_6)
X_6=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_6)
pca_6 = pca.transform(X_6)

# %%
X=pd.DataFrame(centre_7)
X_7=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_7)
pca_7 = pca.transform(X_7)

# %%
X=pd.DataFrame(centre_8)
X_8=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_8)
pca_8 = pca.transform(X_8)

# %%
X=pd.DataFrame(centre_9)
X_9=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_9)
pca_9 = pca.transform(X_9)

# %%
X=pd.DataFrame(centre_10)
X_10=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_10)
pca_10 = pca.transform(X_10)

# %%
X=pd.DataFrame(centre_11)
X_11=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_11)
pca_11 = pca.transform(X_11)

# %%
X=pd.DataFrame(centre_12)
X_12=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_12)
pca_12 = pca.transform(X_12)

# %%
pca_123=[]
pca_12k=[]
for i in range (1000):
    pca_12k.append(np.append(pca_1[i],pca_2[i]))
    pca_123.append(np.append(pca_12k[i],pca_3[i]))

# %%
pca_456=[]
pca_45=[]
for i in range (1000):
    pca_45.append(np.append(pca_4[i],pca_5[i]))
    pca_456.append(np.append(pca_45[i],pca_6[i]))

# %%
pca_789=[]
pca_78=[]
for i in range (1000):
    pca_78.append(np.append(pca_7[i],pca_8[i]))
    pca_789.append(np.append(pca_78[i],pca_9[i]))

# %%
pca_101112=[]
pca_1011=[]
for i in range (1000):
    pca_1011.append(np.append(pca_10[i],pca_11[i]))
    pca_101112.append(np.append(pca_1011[i],pca_12[i]))

# %%
pca_123456=[]
pca_789101112=[]
for i in range (1000):
    pca_123456.append(np.append(pca_123[i],pca_456[i]))
    pca_789101112.append(np.append(pca_789[i],pca_101112[i]))

# %%
##apre quelque experiments et connaisance apriori,j'ai choisi channel 1,2,3 et 7,8,9,10,11,12(car 4,5,6 est combinaison lineaire de 1,2,3)
pca_featureselected=[]
for i in range (1000):
    pca_featureselected.append(np.append(pca_123456[i],pca_789101112[i]))

# %%
pca_12=array(pca_12)

# %%
##classofieur:kmeans par scripts:on choisi les premiere deux channel 
mean1=np.array(pca_12[0,:])
                   
mean2=np.array(pca_12[2,:])
                    
mean3=np.array(pca_12[5,:])

mean4=np.array(pca_12[8,:])

mean5=np.array(pca_12[14,:])

mean6=np.array(pca_12[4,:])

# %%
nm1=0
nm2=0
nm3=0
nm4=0
nm5=0
nm6=0
for i in range (1000):
    test = np.array(pca_12[i,:])
    err = [np.linalg.norm(test-mean1),np.linalg.norm(test-mean2),np.linalg.norm(test-mean3),np.linalg.norm(test-mean4),np.linalg.norm(test-mean5),np.linalg.norm(test-mean6)]
    if err[0] == min(err):
        nm1 += 1
        mean1 = (mean1*nm1+test)/(nm1+1)
    elif err[1] == min(err):
        nm2 += 1
        mean2 = (mean2*nm2+test)/(nm2+1)
    elif err[2] == min(err):
        nm3 += 1
        mean3 = (mean3*nm3+test)/(nm3+1)
    elif err[3] == min(err):
        nm4 += 1
        mean4 = (mean4*nm4+test)/(nm4+1)
    elif err[4] == min(err):
        nm5 += 1
        mean5 = (mean5*nm5+test)/(nm5+1)
    elif err[5] == min(err):
        nm6 += 1
        mean6 = (mean6*nm6+test)/(nm6+1)

# %%
answer=[1 for i in range (1000)]
for i in range (1000):
    test = np.array(pca_12[i,:])
    err = [np.linalg.norm(test-mean1),np.linalg.norm(test-mean2),np.linalg.norm(test-mean3),np.linalg.norm(test-mean4),np.linalg.norm(test-mean5),np.linalg.norm(test-mean6)]
    if err[5] == min(err) or err[1]==min(err):
        answer[i]= 0

# %%
cst=0
for i in range (1000):
    if answer[i] == Ytrain.iloc[i,1]:
        cst += 1
cst
# Out:
# 701

# %%
M  = confusion_matrix(answer,Ytrain.iloc[0:1000,1]) 
M_normalized = M.astype('float') / M.sum(axis=1)[:, np.newaxis]
plt.imshow(M_normalized, interpolation='nearest', cmap=plt.cm.Blues)
plt.colorbar()
#plt.title("Matrice de confusion ")
#plt.tight_layout()
#plt.ylabel(' ')
#plt.xlabel(' ')
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x0000000023180908>
# C:\Users\asus\Anaconda2\lib\site-packages\matplotlib\collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
##deuxieme methode:kmeans de package
from sklearn import cluster
n_clusters = 2
np.random.seed(0)

# %%
X=pca_12
k_means = cluster.KMeans(n_clusters=n_clusters, n_init=4)
k_means.fit(X)
values = k_means.cluster_centers_.squeeze()
labels = k_means.labels_

# %%
cst=0
for i in range (1000):
    if labels[i] == Ytrain.iloc[i,1]:
        cst += 1
cst
# Out:
# 669

# %%
M  = confusion_matrix(labels,Ytrain.iloc[0:1000,1]) 
M_normalized = M.astype('float') / M.sum(axis=1)[:, np.newaxis]
plt.imshow(M_normalized, interpolation='nearest', cmap=plt.cm.Blues)
plt.colorbar()
#plt.title("Matrice de confusion ")
#plt.tight_layout()
#plt.ylabel(' ')
#plt.xlabel(' ')
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x0000000026152248>

# %%
lable = Ytrain.TARGET.values
N_sep = len(lable)*2/3

# %%
##troisme methode:random forest:on choisi pca_featureselected
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=1000)
model.fit(pca_featureselected[0:N_sep], lable[0:N_sep])
print"Taux de Bien CLassés :", model.score(pca_featureselected[N_sep:], lable[N_sep:])
# Out:
# Taux de Bien CLassés : 0.784431137725

# %%
M  = confusion_matrix(labels,Ytrain.iloc[0:1000,1]) 
M_normalized = M.astype('float') / M.sum(axis=1)[:, np.newaxis]
plt.imshow(M_normalized, interpolation='nearest', cmap=plt.cm.Blues)
plt.colorbar()
#plt.title("Matrice de confusion ")
#plt.tight_layout()
#plt.ylabel(' ')
#plt.xlabel(' ')

# %%
##ajouter cross validation pour ameliorer la taux de correct
from sklearn import cross_validation
scores  = cross_validation.cross_val_score(model, pca_featureselected, lable, cv=10)
print(scores)
print "Taux de Bien CLassés :", (np.mean(scores))
# Out:
# [ 0.85148515  0.85148515  0.84        0.86        0.89        0.85        0.85
#   0.91        0.78787879  0.77777778]
# Taux de Bien CLassés : 0.846862686269

# %%
##transform de data:feature selected et pca
test_centre_1=[]
channel = 1
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (353):
    Xtest_num  = Xtest.iloc[i,columne]
    A=pd.Series(Xtest_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    test_centre_1.append(centre_loc)

# %%
test_centre_2=[]
channel = 2
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (353):
    Xtest_num  = Xtest.iloc[i,columne]
    A=pd.Series(Xtest_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    test_centre_2.append(centre_loc)

# %%
test_centre_3=[]
channel = 3
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (353):
    Xtest_num  = Xtest.iloc[i,columne]
    A=pd.Series(Xtest_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    test_centre_3.append(centre_loc)

# %%
test_centre_4=[]
channel = 4
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (353):
    Xtest_num  = Xtest.iloc[i,columne]
    A=pd.Series(Xtest_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    test_centre_4.append(centre_loc)

# %%
test_centre_5=[]
channel = 5
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (353):
    Xtest_num  = Xtest.iloc[i,columne]
    A=pd.Series(Xtest_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    test_centre_5.append(centre_loc)

# %%
test_centre_6=[]
channel = 6
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (353):
    Xtest_num  = Xtest.iloc[i,columne]
    A=pd.Series(Xtest_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    test_centre_6.append(centre_loc)

# %%
test_centre_7=[]
channel = 7
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (353):
    Xtest_num  = Xtest.iloc[i,columne]
    A=pd.Series(Xtest_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    test_centre_7.append(centre_loc)

# %%
test_centre_8=[]
channel = 8
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (353):
    Xtest_num  = Xtest.iloc[i,columne]
    A=pd.Series(Xtest_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    test_centre_8.append(centre_loc)

# %%
test_centre_9=[]
channel = 9
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (353):
    Xtest_num  = Xtest.iloc[i,columne]
    A=pd.Series(Xtest_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    test_centre_9.append(centre_loc)

# %%
test_centre_10=[]
channel = 10
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (353):
    Xtest_num  = Xtest.iloc[i,columne]
    A=pd.Series(Xtest_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    test_centre_10.append(centre_loc)

# %%
test_centre_11=[]
channel = 11
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (353):
    Xtest_num  = Xtest.iloc[i,columne]
    A=pd.Series(Xtest_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    test_centre_11.append(centre_loc)

# %%
test_centre_12=[]
channel = 12
columne = [j for j in range((channel-1)*750,750*channel-1)]
for i in range (353):
    Xtest_num  = Xtest.iloc[i,columne]
    A=pd.Series(Xtest_num).tolist()
    index=0
    B=max(np.abs(A[33:684]))
    for j in range(749):
        if A[j] == B:
            index=j
    centre_loc=[]
    for j in range(index-33,index+66):
        centre_loc.append(A[j])
    test_centre_12.append(centre_loc)

# %%
X=pd.DataFrame(test_centre_1)
X_1_test=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_1_test)
pca_1_test = pca.transform(X_1_test)

# %%
X=pd.DataFrame(test_centre_2)
X_2_test=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_2_test)
pca_2_test = pca.transform(X_2_test)

# %%
X=pd.DataFrame(test_centre_3)
X_3_test=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_3_test)
pca_3_test = pca.transform(X_3_test)

# %%
X=pd.DataFrame(test_centre_4)
X_4_test=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_4_test)
pca_4_test = pca.transform(X_4_test)

# %%
X=pd.DataFrame(test_centre_5)
X_5_test=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_5_test)
pca_5_test = pca.transform(X_5_test)

# %%
X=pd.DataFrame(test_centre_6)
X_6_test=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_6_test)
pca_6_test = pca.transform(X_6_test)

# %%
X=pd.DataFrame(test_centre_7)
X_7_test=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_7_test)
pca_7_test = pca.transform(X_7_test)

# %%
X=pd.DataFrame(test_centre_8)
X_8_test=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_8_test)
pca_8_test = pca.transform(X_8_test)

# %%
X=pd.DataFrame(test_centre_9)
X_9_test=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_9_test)
pca_9_test = pca.transform(X_9_test)

# %%
X=pd.DataFrame(test_centre_10)
X_10_test=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_10_test)
pca_10_test = pca.transform(X_10_test)

# %%
X=pd.DataFrame(test_centre_11)
X_11_test=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_11_test)
pca_11_test = pca.transform(X_11_test)

# %%
X=pd.DataFrame(test_centre_12)
X_12_test=preprocessing.scale(X)
pca = PCA(n_components=20)
pca.fit(X_12_test)
pca_12_test = pca.transform(X_12_test)

# %%
pca_123_test=[]
pca_12k_test=[]
for i in range (353):
    pca_12k_test.append(np.append(pca_1_test[i],pca_2_test[i]))
    pca_123_test.append(np.append(pca_12k_test[i],pca_3_test[i]))

# %%
pca_456_test=[]
pca_45_test=[]
for i in range (353):
    pca_45_test.append(np.append(pca_4_test[i],pca_5_test[i]))
    pca_456_test.append(np.append(pca_45_test[i],pca_6_test[i]))

# %%
pca_789_test=[]
pca_78_test=[]
for i in range (353):
    pca_78_test.append(np.append(pca_7_test[i],pca_8_test[i]))
    pca_789_test.append(np.append(pca_78_test[i],pca_9_test[i]))

# %%
pca_101112_test=[]
pca_1011_test=[]
for i in range (353):
    pca_1011_test.append(np.append(pca_10_test[i],pca_11_test[i]))
    pca_101112_test.append(np.append(pca_1011_test[i],pca_12_test[i]))

# %%
pca_123456_test=[]
pca_789101112_test=[]
for i in range (353):
    pca_123456_test.append(np.append(pca_123_test[i],pca_456_test[i]))
    pca_789101112_test.append(np.append(pca_789_test[i],pca_101112_test[i]))

# %%
pca_featureselected_test=[]
for i in range (353):
    pca_featureselected_test.append(np.append(pca_123456_test[i],pca_789101112_test[i]))

# %%
Ytest=model.predict(pca_featureselected_test)
